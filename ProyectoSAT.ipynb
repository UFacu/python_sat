# %%
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/Fifa_23_Players_Data.csv.zip')
df
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 17524      D. Collins      Darren Collins       47         56          110000
# 17525    Yang Dejiang        Dejiang Yang       47         57           90000
# 17526       L. Mullan         Liam Mullan       47         67          130000
# 17527    D. McCallion    Daithí McCallion       47         61          100000
# 17528        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 17524            ST,RM           CAM  Republic of Ireland
# 17525              CDM           CDM             China PR
# 17526               CM            RM     Northern Ireland
# 17527               CB            CB  Republic of Ireland
# 17528               LB            LB                India
#
#                                              Image Link  Age  ...  LM Rating  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...         86
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...         91
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...         92
# ...                                                 ...  ...  ...        ...
# 17524  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...         50
# 17525  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...         45
# 17526  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...         52
# 17527  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...         33
# 17528  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...         44
#
#        CM Rating  RM Rating  LWB Rating CDM Rating  RWB Rating  LB Rating  \
# 0             88         91          67         66          67         62
# 1             84         89          67         67          67         63
# 2             83         86          67         69          67         64
# 3             91         91          82         82          82         78
# 4             84         92          70         66          70         66
# ...          ...        ...         ...        ...         ...        ...
# 17524         44         50          41         38          41         40
# 17525         45         45          47         48          47         49
# 17526         49         52          46         44          46         46
# 17527         33         33          44         42          44         47
# 17528         40         44          46         43          46         47
#
#       CB Rating RB Rating GK Rating
# 0            53        62        22
# 1            58        63        21
# 2            63        64        22
# 3            72        78        24
# 4            57        66        21
# ...         ...       ...       ...
# 17524        36        40        15
# 17525        49        49        15
# 17526        42        46        17
# 17527        49        47        15
# 17528        47        47        19
#
# [17529 rows x 89 columns]

# %% [markdown]
# 1) Limpiamos el dataset: Con las siguientes funciones analizamos los datos para ver si podemos encontrar algun error, tambien utilizamos la funcion duplicate para ver si hay filas repetidas

# %%
df.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  LM Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# 2  https://cdn.sofifa.net/players/188/545/23_60.png   33  ...         86
# 3  https://cdn.sofifa.net/players/192/985/23_60.png   31  ...         91
# 4  https://cdn.sofifa.net/players/231/747/23_60.png   23  ...         92
#
#    CM Rating  RM Rating  LWB Rating CDM Rating  RWB Rating  LB Rating  \
# 0         88         91          67         66          67         62
# 1         84         89          67         67          67         63
# 2         83         86          67         69          67         64
# 3         91         91          82         82          82         78
# 4         84         92          70         66          70         66
#
#   CB Rating RB Rating GK Rating
# 0        53        62        22
# 1        58        63        21
# 2        63        64        22
# 3        72        78        24
# 4        57        66        21
#
# [5 rows x 89 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17529 entries, 0 to 17528
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Known As                     17529 non-null  object
#  1   Full Name                    17529 non-null  object
#  2   Overall                      17529 non-null  int64
#  3   Potential                    17529 non-null  int64
#  4   Value(in Euro)               17529 non-null  int64
#  5   Positions Played             17529 non-null  object
#  6   Best Position                17529 non-null  object
#  7   Nationality                  17529 non-null  object
#  8   Image Link                   17529 non-null  object
#  9   Age                          17529 non-null  int64
#  10  Height(in cm)                17529 non-null  int64
#  11  Weight(in kg)                17529 non-null  int64
#  12  TotalStats                   17529 non-null  int64
#  13  BaseStats                    17529 non-null  int64
#  14  Club Name                    17529 non-null  object
#  15  Wage(in Euro)                17529 non-null  int64
#  16  Release Clause               17529 non-null  int64
#  17  Club Position                17529 non-null  object
#  18  Contract Until               17529 non-null  object
#  19  Club Jersey Number           17529 non-null  object
#  20  Joined On                    17529 non-null  int64
#  21  On Loan                      17529 non-null  object
#  22  Preferred Foot               17529 non-null  object
#  23  Weak Foot Rating             17529 non-null  int64
#  24  Skill Moves                  17529 non-null  int64
#  25  International Reputation     17529 non-null  int64
#  26  National Team Name           17529 non-null  object
#  27  National Team Image Link     17529 non-null  object
#  28  National Team Position       17529 non-null  object
#  29  National Team Jersey Number  17529 non-null  object
#  30  Attacking Work Rate          17529 non-null  object
#  31  Defensive Work Rate          17529 non-null  object
#  32  Pace Total                   17529 non-null  int64
#  33  Shooting Total               17529 non-null  int64
#  34  Passing Total                17529 non-null  int64
#  35  Dribbling Total              17529 non-null  int64
#  36  Defending Total              17529 non-null  int64
#  37  Physicality Total            17529 non-null  int64
#  38  Crossing                     17529 non-null  int64
#  39  Finishing                    17529 non-null  int64
#  40  Heading Accuracy             17529 non-null  int64
#  41  Short Passing                17529 non-null  int64
#  42  Volleys                      17529 non-null  int64
#  43  Dribbling                    17529 non-null  int64
#  44  Curve                        17529 non-null  int64
#  45  Freekick Accuracy            17529 non-null  int64
#  46  LongPassing                  17529 non-null  int64
#  47  BallControl                  17529 non-null  int64
#  48  Acceleration                 17529 non-null  int64
#  49  Sprint Speed                 17529 non-null  int64
#  50  Agility                      17529 non-null  int64
#  51  Reactions                    17529 non-null  int64
#  52  Balance                      17529 non-null  int64
#  53  Shot Power                   17529 non-null  int64
#  54  Jumping                      17529 non-null  int64
#  55  Stamina                      17529 non-null  int64
#  56  Strength                     17529 non-null  int64
#  57  Long Shots                   17529 non-null  int64
#  58  Aggression                   17529 non-null  int64
#  59  Interceptions                17529 non-null  int64
#  60  Positioning                  17529 non-null  int64
#  61  Vision                       17529 non-null  int64
#  62  Penalties                    17529 non-null  int64
#  63  Composure                    17529 non-null  int64
#  64  Marking                      17529 non-null  int64
#  65  Standing Tackle              17529 non-null  int64
#  66  Sliding Tackle               17529 non-null  int64
#  67  Goalkeeper Diving            17529 non-null  int64
#  68  Goalkeeper Handling          17529 non-null  int64
#  69   GoalkeeperKicking           17529 non-null  int64
#  70  Goalkeeper Positioning       17529 non-null  int64
#  71  Goalkeeper Reflexes          17529 non-null  int64
#  72  ST Rating                    17529 non-null  int64
#  73  LW Rating                    17529 non-null  int64
#  74  LF Rating                    17529 non-null  int64
#  75  CF Rating                    17529 non-null  int64
#  76  RF Rating                    17529 non-null  int64
#  77  RW Rating                    17529 non-null  int64
#  78  CAM Rating                   17529 non-null  int64
#  79  LM Rating                    17529 non-null  int64
#  80  CM Rating                    17529 non-null  int64
#  81  RM Rating                    17529 non-null  int64
#  82  LWB Rating                   17529 non-null  int64
#  83  CDM Rating                   17529 non-null  int64
#  84  RWB Rating                   17529 non-null  int64
#  85  LB Rating                    17529 non-null  int64
#  86  CB Rating                    17529 non-null  int64
#  87  RB Rating                    17529 non-null  int64
#  88  GK Rating                    17529 non-null  int64
# dtypes: int64(71), object(18)
# memory usage: 11.9+ MB

# %%
df.describe()
# Out:
#             Overall     Potential  Value(in Euro)           Age  \
# count  17529.000000  17529.000000    1.752900e+04  17529.000000
# mean      65.943237     71.043471    2.931541e+06     25.296081
# std        6.796701      6.172603    7.816143e+06      4.722269
# min       47.000000     48.000000    0.000000e+00     16.000000
# 25%       62.000000     67.000000    5.000000e+05     22.000000
# 50%       66.000000     71.000000    1.000000e+06     25.000000
# 75%       70.000000     75.000000    2.000000e+06     29.000000
# max       91.000000     95.000000    1.905000e+08     44.000000
#
#        Height(in cm)  Weight(in kg)    TotalStats     BaseStats  \
# count   17529.000000   17529.000000  17529.000000  17529.000000
# mean      181.626847      75.224827   1603.559929    358.365109
# std         6.832866       7.013211    274.139404     39.652407
# min       155.000000      49.000000    759.000000    224.000000
# 25%       177.000000      70.000000   1471.000000    331.000000
# 50%       182.000000      75.000000   1642.000000    359.000000
# 75%       186.000000      80.000000   1789.000000    385.000000
# max       206.000000     105.000000   2312.000000    502.000000
#
#        Wage(in Euro)  Release Clause  ...     LM Rating     CM Rating  \
# count   17529.000000    1.752900e+04  ...  17529.000000  17529.000000
# mean     9006.942781    5.171944e+06  ...     58.484112     57.429060
# std     19851.989326    1.501628e+07  ...     14.035482     13.217884
# min         0.000000    0.000000e+00  ...     18.000000     18.000000
# 25%      1000.000000    6.740000e+05  ...     54.000000     53.000000
# 50%      3000.000000    1.500000e+06  ...     62.000000     60.000000
# 75%      8000.000000    3.400000e+06  ...     67.000000     66.000000
# max    450000.000000    3.667000e+08  ...     92.000000     91.000000
#
#           RM Rating    LWB Rating    CDM Rating    RWB Rating     LB Rating  \
# count  17529.000000  17529.000000  17529.000000  17529.000000  17529.000000
# mean      58.484112     56.308346     55.975812     56.308346     55.675908
# std       14.035482     13.949071     13.912260     13.949071     14.202017
# min       18.000000     17.000000     19.000000     17.000000     17.000000
# 25%       54.000000     51.000000     49.000000     51.000000     49.000000
# 50%       62.000000     59.000000     59.000000     59.000000     59.000000
# 75%       67.000000     66.000000     66.000000     66.000000     65.000000
# max       92.000000     88.000000     89.000000     88.000000     87.000000
#
#           CB Rating     RB Rating     GK Rating
# count  17529.000000  17529.000000  17529.000000
# mean      54.566775     55.675908     23.325689
# std       14.782078     14.202017     15.187771
# min       18.000000     17.000000     10.000000
# 25%       45.000000     49.000000     17.000000
# 50%       58.000000     59.000000     18.000000
# 75%       66.000000     65.000000     20.000000
# max       90.000000     87.000000     90.000000
#
# [8 rows x 71 columns]

# %%
 df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17524    False
# 17525    False
# 17526    False
# 17527    False
# 17528    False
# Length: 17529, dtype: bool

# %% [markdown]
# 2) Realizamos graficos para poder sacar conclusiones

# %%
my_df = df.head(100)
final_df= my_df.iloc[:, [0, 1, 2, 3, 4 ,5 ,6 ,7]]
final_df
# Out:
#           Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0         L. Messi        Lionel Messi       91         91        54000000
# 1       K. Benzema       Karim Benzema       91         91        64000000
# 2   R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3     K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4        K. Mbappé       Kylian Mbappé       91         95       190500000
# ..             ...                 ...      ...        ...             ...
# 95      D. Mertens       Dries Mertens       84         84        18000000
# 96       L. Suárez         Luis Suárez       84         84        18000000
# 97        D. Tadić         Dušan Tadić       84         84        26500000
# 98      D. Berardi    Domenico Berardi       84         84        45000000
# 99       T. Partey       Thomas Partey       84         84        36000000
#
#    Positions Played Best Position Nationality
# 0                RW           CAM   Argentina
# 1             CF,ST            CF      France
# 2                ST            ST      Poland
# 3            CM,CAM            CM     Belgium
# 4             ST,LW            ST      France
# ..              ...           ...         ...
# 95        CF,ST,CAM            CF     Belgium
# 96               ST            ST     Uruguay
# 97        LW,CF,CAM            LW      Serbia
# 98            RM,RW            RM       Italy
# 99           CDM,CM           CDM       Ghana
#
# [100 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(data=final_df,x=final_df['Overall'], y=final_df['Nationality'])

# Agregamos titulos y etiquetas
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')

# Mostrar
plt.show()

# %%
values = final_df['Value(in Euro)']
plt.hist(values, bins=10, edgecolor='black')
plt.xlabel('Player Value (in Euro)')
plt.ylabel('Frequency')
plt.title('Distribution of Player Values')

plt.show()

# %%
sns.lineplot(data=final_df,x=final_df['Value(in Euro)'], y=final_df['Overall'])

# Agregar etiquetas y título
plt.xlabel('Valor en euros')
plt.ylabel('Puntuación')
plt.title('Relación entre Valor del jugador y Puntuación de los Jugadores')

# Mostrar el gráfico
plt.show()

# %%
jugadores_filtrados = df[(df['Age'] < 23) & (df['Overall'] > 80)]

# Obtener los nombres de los primeros 40 jugadores
nombres_jugadores = jugadores_filtrados['Full Name'].head(40)
print(nombres_jugadores)
# Out:
# 21                       Erling Haaland
# 63     Vinícius José de Oliveira Júnior
# 82                 Pedro González López
# 83                           Phil Foden
# 84                     Matthijs de Ligt
# 124                     Jude Bellingham
# 126                        Moussa Diaby
# 131                       Sandro Tonali
# 136                         Reece James
# 139                 João Félix Sequeira
# 141                     Alphonso Davies
# 144                        Jadon Sancho
# 152                      Dušan Vlahović
# 225                       Florian Wirtz
# 226           Antony Matheus dos Santos
# 228                  Nico Schlotterbeck
# 229                         Bukayo Saka
# 231                 Aurélien Tchouaméni
# 232                Ferran Torres García
# 241      Lucas Luciano Mantela Patrício
# 277                         Evan Ndicka
# 288                      Nicolò Zaniolo
# 291         Pedro Antonio Porro Sauceda
# 296               Rodrygo Silva de Goes
# 298                    Dejan Kulusevski
# 300                      Joško Gvardiol
# 301                       Jamal Musiala
# 302                        Sam Obisanya
# 310      Welington Kauê Dano Nascimento
# 312      Rosival Jailson Dourado Santos
# Name: Full Name, dtype: object

# %%
# Crear el gráfico de barras
plt.bar(df['Best Position'], df['Value(in Euro)'])

# Personalizar el gráfico
plt.title('Gráfico de Barras')
plt.xlabel('Posicion')
plt.ylabel('Valor')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Conclusion:
#
# Gráfico 1:
# Un gráfico de línea que cruza la nacionalidad con la puntuación de los jugadores permite observar cómo varía el rendimiento promedio de los jugadores según su nacionalidad a lo largo del tiempo. En este caso, paises como Argentina,Francia, Polinia tienen jugadores con mayor global.
#
# Gráfico 2:
# Se pueden obtener conclusiones sobre los rangos de precios más comunes, el precio medio, la presencia de valores atípicos y las comparaciones de frecuencias entre diferentes rangos de precios. Este análisis proporciona información sobre la distribución general de los precios de los jugadores en la base de datos.
#
# Gráfico 3:
# Este gráfico muestra que el precio no esta relacionado con el global(puntuación) del jugador. (excepto para los mejroes jugadores del mundo el cual si esta directamente relacionado)
#
# Anális 1:
# Determinar los jugadores con las calificaciones más altas en diferentes aspectos y habilidades ayuda a identificar a los jugadores más destacados y valiosos en términos de su rendimiento y habilidades específicas.
#
# Gráfico 5:
# Mediante este grafico de barras que compara la mejor posicion del jugador con su valor en el mercado se observa  que la unica posicion que "vale mas" es la  CF (segundo delantero derecho).
